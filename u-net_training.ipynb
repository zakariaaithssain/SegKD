# %%
! git clone https://github.com/zakariaaithssain/SegKD.git
# %cd SegKD
# Out:
# Cloning into 'SegKD'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 52 (delta 0), reused 0 (delta 0), pack-reused 51 (from 1)
# Receiving objects: 100% (52/52), 93.67 MiB | 38.03 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /kaggle/working/SegKD

# %%
! pip install segmentation_models_pytorch
# Out:
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (1.4.1)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (11.3.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (0.7.0)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (1.0.25)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (0.25.0+cu128)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from segmentation_models_pytorch) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (6.0.3)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (1.5.4)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation_models_pytorch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation_models_pytorch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.8->segmentation_models_pytorch) (1.3.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation_models_pytorch) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8->segmentation_models_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8->segmentation_models_pytorch) (3.0.3)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub>=0.24->segmentation_models_pytorch) (0.24.1)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.24->segmentation_models_pytorch) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.24->segmentation_models_pytorch) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.24->segmentation_models_pytorch) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.24->segmentation_models_pytorch) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.24->segmentation_models_pytorch) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.24->segmentation_models_pytorch) (0.1.2)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: segmentation_models_pytorch
# Successfully installed segmentation_models_pytorch-0.5.0

# %%
import kagglehub
path = kagglehub.dataset_download("lakshaymiddha/crack-segmentation-dataset") + "/crack_segmentation_dataset"
print("Path to dataset files:", path)

import os, shutil, random

src_images = f'{path}/images'
src_masks  = f'{path}/masks'

random.seed(42)
files = sorted(os.listdir(src_images))
random.shuffle(files)

n       = len(files)
n_train = int(n * 0.70)
n_val   = int(n * 0.15)

splits = {
    'train' : files[:n_train],
    'val'   : files[n_train:n_train + n_val],
    'test'  : files[n_train + n_val:],
}

for split, subset in splits.items():
    os.makedirs(f'data/{split}/images', exist_ok=True)
    os.makedirs(f'data/{split}/masks',  exist_ok=True)
    for f in subset:
        mask_f = f if os.path.exists(f'{src_masks}/{f}') else f.replace('.jpg', '.png')
        shutil.copy(f'{src_images}/{f}',     f'data/{split}/images/{f}')
        shutil.copy(f'{src_masks}/{mask_f}', f'data/{split}/masks/{mask_f}')
    print(f'{split}: {len(subset)} images')
# Out:
# Path to dataset files: /kaggle/input/datasets/lakshaymiddha/crack-segmentation-dataset/crack_segmentation_dataset
# train: 7908 images
# val: 1694 images
# test: 1696 images

# %%
# !python src/train.py --mode student --epochs 50 --batch_size 10
# Out:
#   Device : cuda
# [train] 7908 images chargées
# [val] 1694 images chargées
# [test] 1696 images chargées
#
# =======================================================
#   MODE : STUDENT SEUL (sans distillation)
# =======================================================
# config.json: 100%|██████████████████████████████| 106/106 [00:00<00:00, 306kB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: 100%|███████████████████| 14.2M/14.2M [00:00<00:00, 16.4MB/s]
#   Epoch [001/50]  Loss: 0.4132  IoU: 0.4661  F1: 0.6045
#   ✓ Checkpoint sauvegardé → checkpoints/student_alone_best.pth
#   Epoch [002/50]  Loss: 0.2359  IoU: 0.4917  F1: 0.6262
#   ✓ Checkpoint sauvegardé → checkpoints/student_alone_best.pth
#   Epoch [003/50]  Loss: 0.2095  IoU: 0.4792  F1: 0.6129
#   Epoch [004/50]  Loss: 0.2020  IoU: 0.5072  F1: 0.6411
#   ✓ Checkpoint sauvegardé → checkpoints/student_alone_best.pth
#   Epoch [005/50]  Loss: 0.1979  IoU: 0.5082  F1: 0.6415
#   ✓ Checkpoint sauvegardé → checkpoints/student_alone_best.pth
#   Epoch [006/50]  Loss: 0.1964  IoU: 0.5337  F1: 0.6664
#   ✓ Checkpoint sauvegardé → checkpoints/student_alone_best.pth
#   Epoch [007/50]  Loss: 0.1934  IoU: 0.5334  F1: 0.6659
#   Epoch [008/50]  Loss: 0.1922  IoU: 0.5575  F1: 0.6892
#   ✓ Checkpoint sauvegardé → checkpoints/student_alone_best.pth
#   Epoch [009/50]  Loss: 0.1894  IoU: 0.5167  F1: 0.6495
#   Epoch [010/50]  Loss: 0.1892  IoU: 0.5711  F1: 0.7031
#   ✓ Checkpoint sauvegardé → checkpoints/student_alone_best.pth
#   Epoch [011/50]  Loss: 0.1869  IoU: 0.5682  F1: 0.6993
#   Epoch [012/50]  Loss: 0.1850  IoU: 0.5655  F1: 0.6978
#   Epoch [013/50]  Loss: 0.1857  IoU: 0.5656  F1: 0.6971
#   Epoch [014/50]  Loss: 0.1828  IoU: 0.5879  F1: 0.7189
#   ✓ Checkpoint sauvegardé → checkpoints/student_alone_best.pth
#   Epoch [015/50]  Loss: 0.1819  IoU: 0.5832  F1: 0.7138
#   Epoch [016/50]  Loss: 0.1813  IoU: 0.5960  F1: 0.7264
#   ✓ Checkpoint sauvegardé → checkpoints/student_alone_best.pth
#   Epoch [017/50]  Loss: 0.1797  IoU: 0.5752  F1: 0.7058
