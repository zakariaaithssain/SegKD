# %%
! git clone https://github.com/zakariaaithssain/SegKD
# Out:
# Cloning into 'SegKD'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 46 (delta 18), reused 39 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 1.45 MiB | 11.58 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
cd SegKD
# Out:
# /kaggle/working/SegKD

# %%
import kagglehub
path = kagglehub.dataset_download("lakshaymiddha/crack-segmentation-dataset") + "/crack_segmentation_dataset"
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/datasets/lakshaymiddha/crack-segmentation-dataset/crack_segmentation_dataset

# %%
import os, shutil, random

path ="/kaggle/input/datasets/lakshaymiddha/crack-segmentation-dataset/crack_segmentation_dataset"
src_images = f'{path}/images'
src_masks  = f'{path}/masks'

random.seed(42)
files = sorted(os.listdir(src_images))
random.shuffle(files)

n       = len(files)
n_train = int(n * 0.70)
n_val   = int(n * 0.15)

splits = {
    'train' : files[:n_train],
    'val'   : files[n_train:n_train + n_val],
    'test'  : files[n_train + n_val:],
}

for split, subset in splits.items():
    os.makedirs(f'data/{split}/images', exist_ok=True)
    os.makedirs(f'data/{split}/masks',  exist_ok=True)
    for f in subset:
        mask_f = f if os.path.exists(f'{src_masks}/{f}') else f.replace('.jpg', '.png')
        shutil.copy(f'{src_images}/{f}',     f'data/{split}/images/{f}')
        shutil.copy(f'{src_masks}/{mask_f}', f'data/{split}/masks/{mask_f}')
    print(f'{split}: {len(subset)} images')
# Out:
# train: 7908 images
# val: 1694 images
# test: 1696 images

# %%
# !python src/dataset.py
# Out:
# [train] 7908 images chargées
# [val] 1694 images chargées
# [test] 1696 images chargées
# Batch images : torch.Size([4, 3, 512, 512])
# Batch masques : torch.Size([4, 1, 512, 512])
# Valeurs masque : tensor([0., 1.])

# %%
# !pip install -q albumentations tabulate segmentation-models-pytorch kagglehub google
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 4.4 MB/s eta 0:00:00

# %%
# !python src/train.py --mode teacher --epochs 24 --batch_size 10 --img_size 512
# Out:
#   Device : cuda
# [train] 7908 images chargées
# [val] 1694 images chargées
# [test] 1696 images chargées
#
# =======================================================
#   MODE : TEACHER (U-Net++)
# =======================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100%|██████████████████████████████| 156/156 [00:00<00:00, 756kB/s]
# model.safetensors: 100%|███████████████████| 87.3M/87.3M [00:01<00:00, 78.6MB/s]
#   Epoch [001/24]  Loss: 0.3695  IoU: 0.4995  F1: 0.6332
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [002/24]  Loss: 0.2248  IoU: 0.5221  F1: 0.6534
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [003/24]  Loss: 0.2065  IoU: 0.5707  F1: 0.7039
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [004/24]  Loss: 0.1996  IoU: 0.5599  F1: 0.6924
#   Epoch [005/24]  Loss: 0.1962  IoU: 0.5442  F1: 0.6753
#   Epoch [006/24]  Loss: 0.1929  IoU: 0.5083  F1: 0.6403
#   Epoch [007/24]  Loss: 0.1909  IoU: 0.5733  F1: 0.7045
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [008/24]  Loss: 0.1868  IoU: 0.5832  F1: 0.7149
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [009/24]  Loss: 0.1868  IoU: 0.5917  F1: 0.7224
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [010/24]  Loss: 0.1863  IoU: 0.5698  F1: 0.7009
#   Epoch [011/24]  Loss: 0.1803  IoU: 0.5946  F1: 0.7246
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [012/24]  Loss: 0.1806  IoU: 0.5844  F1: 0.7144
#   Epoch [013/24]  Loss: 0.1788  IoU: 0.5938  F1: 0.7235
#   Epoch [014/24]  Loss: 0.1754  IoU: 0.6001  F1: 0.7293
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [015/24]  Loss: 0.1742  IoU: 0.5950  F1: 0.7245
#   Epoch [016/24]  Loss: 0.1721  IoU: 0.5910  F1: 0.7201
#   Epoch [017/24]  Loss: 0.1712  IoU: 0.6090  F1: 0.7378
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [018/24]  Loss: 0.1696  IoU: 0.5979  F1: 0.7267
#   Epoch [019/24]  Loss: 0.1685  IoU: 0.5929  F1: 0.7214
#   Epoch [020/24]  Loss: 0.1673  IoU: 0.5931  F1: 0.7212
#   Epoch [021/24]  Loss: 0.1671  IoU: 0.6057  F1: 0.7339
#   Epoch [022/24]  Loss: 0.1664  IoU: 0.5949  F1: 0.7231
#   Epoch [023/24]  Loss: 0.1662  IoU: 0.6002  F1: 0.7284
#   Epoch [024/24]  Loss: 0.1660  IoU: 0.6061  F1: 0.7342
#
#   Meilleur IoU Teacher : 0.6090
